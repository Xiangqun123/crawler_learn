# %%
# 导入requests包
import requests

# %%
response = requests.get("https://www.hcittech.cn")

# %%
# 基本使用，response的type，response基本的属性，status_code, text, cookies, headers等
print(type(response))
print(response.status_code)
print(response.text)
print(response.cookies)
print(response.headers)
# Out:
# <class 'requests.models.Response'>
# 200
# ﻿<!DOCTYPE HTML>
# <html>
# <head>
# 	<link rel="shortcut icon" href="/static/favicon.ico" type="image/x-icon"/>
# 	<title>华晨 为您提供最优质的服务</title></head>
# <link href="/static/css/bootstrap.css" rel='stylesheet' type='text/css' />
# <!-- jQuery (necessary for Bootstrap's JavaScript plugins) -->
# <script src="/static/js/jquery.min.js"></script>
# <!---- start-smoth-scrolling---->
# <script type="text/javascript">
# 		jQuery(document).ready(function($) {
# 			$(".scroll").click(function(event){
# 				event.preventDefault();
# 				$('html,body').animate({scrollTop:$(this.hash).offset().top},1200);
# 			});
# 		});
# 	</script>
# <!---- start-smoth-scrolling---->
# <!-- Custom Theme files -->
# <link href="/static/css/style.css" rel='stylesheet' type='text/css' />
# <!-- Custom Theme files -->
# <meta name="viewport" content="width=device-width, initial-scale=1">
# ...

# %%
# post, head, put等方法请求
print(requests.post("http://httpbin.org/post"))
print(requests.head("http://httpbin.org/get"))
print(requests.put("http://httpbin.org/put"))
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
response = requests.get("http://httpbin.org/get")
print(response.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.21.0"
#   },
#   "origin": "125.44.112.71",
#   "url": "http://httpbin.org/get"
# }

# %%
# 含参数请求，直接法，？&
response = requests.get("http://httpbin.org/get?name=xq&age=22")
print(response.text)
# Out:
# {
#   "args": {
#     "age": "22",
#     "name": "xq"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.21.0"
#   },
#   "origin": "125.44.113.9",
#   "url": "http://httpbin.org/get?name=xq&age=22"
# }

# %%
# 带有参数的请求，params法
data = {
    "name":"xq",
    "age":22,
}
response = requests.get("http://httpbin.org/get", params=data)
print(response.text)
# Out:
# {
#   "args": {
#     "age": "22",
#     "name": "xq"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.21.0"
#   },
#   "origin": "125.44.113.9",
#   "url": "http://httpbin.org/get?name=xq&age=22"
# }

# %%
# 返回json字段, 相当于json.loads(response.text), ajax请求
import json
response = requests.get("http://httpbin.org/get")
print(type(response.text))
print(json.loads(response.text))
print(response.json())
print(type(response.json()))
# Out:
# <class 'str'>
# {'args': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Connection': 'close', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.21.0'}, 'origin': '125.44.113.9', 'url': 'http://httpbin.org/get'}
# {'args': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Connection': 'close', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.21.0'}, 'origin': '125.44.113.9', 'url': 'http://httpbin.org/get'}
# <class 'dict'>

# %%
response = requests.get("https://www.hcittech.cn/static/images/logo.png")
print(type(response.text), type(response.content))
print(response.text)
print(response.content)
# Out:
# <class 'str'> <class 'bytes'>
# �PNG
#
# ����[�+y@@�uwU��zZ�]�ul�� ��("T�YIEND�B`�
# ...

# %%
# 爬取二进制图片
with open("hcittech.png","wb") as f:
    f.write(response.content)
    f.close()

# %%
# 添加headers
response = requests.get('https://www.zhihu.com/explore')
print(response.text)
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.81 Safari/537.36'
}
response = requests.get('https://www.zhihu.com/explore', headers=headers)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" dropEffect="none" class="no-js no-auth ">
# <head>
# <meta charset="utf-8" />
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <meta name="renderer" content="webkit" />
# <meta http-equiv="X-ZA-Response-Id" content="f6e14219c88b3c43cb618afe2dce1216">
#
# <meta http-equiv="X-ZA-Experiment" content="default:None,ge3:ge3_9,ge2:ge2_1,nwebQAGrowth:experiment,is_office:false,nweb_growth_people:default,app_store_rate_dialog:close,nweb_search_suggest:default,live_store:ls_a2_b2_c1_f2,nweb_search:nweb_search_heifetz,search_hybrid_tabs:pin-3#album-7,new_live_feed_mediacard:new,hybrid_zhmore_video:yes,ad_r:a,growth_search:s2,qaweb_related_readings_content_control:close,android_pass_through_push:all,android_search_tab_style:search_tab_style_b,android_db_recommend_action:open,android_db_feed_hash_tag_style:button,is_new_noti_panel:no">
# <title>发现 - 知乎</title>
#
# ...

# %%
data = {'name':'zxq', 'age':20}
headers = {'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.81 Safari/537.36'}
response = requests.post("http://www.httpbin.org/post", data=data, headers=headers)
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "age": "20",
#     "name": "zxq"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Content-Length": "15",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "www.httpbin.org",
#     "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.81 Safari/537.36"
#   },
#   "json": null,
#   "origin": "125.44.113.9",
#   "url": "http://www.httpbin.org/post"
# }

# %%
import requests
response = requests.get('http://www.jianshu.com/hello.html')
exit() if not response.status_code == 404 else print('404')

# %%
import requests
files = {'file':open('hcittech.png', 'rb')}
response = requests.post("http://httpbin.org/post", files=files)
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {
#     "file": "data:application/octet-stream;base64,..."
#   },
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Content-Length": "1776",
#     "Content-Type": "multipart/form-data; boundary=f4d3effbcc3df9ae717b948233aca529",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.21.0"
#   },
#   "json": null,
#   "origin": "125.44.113.9",
#   "url": "http://httpbin.org/post"
# }

# %%
# 获取cookies
import requests
response = requests.get('https://www.baidu.com')
print(response.cookies)
for key,value in response.cookies.items():
    print(key+'='+value)
# Out:
# <RequestsCookieJar[<Cookie BDORZ=27315 for .baidu.com/>]>
# BDORZ=27315

# %%
import requests 
# 声明一个Session对象
s = requests.Session()
s.get('http://httpbin.org/cookies/set/number/12345')
response = s.get('http://httpbin.org/cookies')
print(response.text)
# Out:
# {
#   "cookies": {
#     "number": "12345"
#   }
# }

# %%
# 处理证书问题
import requests
from requests.packages import urllib3 
urllib3.disable_warnings()
response = requests.get('https://www.12306.cn', verify=False)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <title>ä¸­å½éè·¯12306</title>
#     <script>
#         window.startTime = new Date().getTime(); //"window.onloadå¤å¼å§æ¶é´:",window.startTime
#     </script>
#     <link rel="shortcut icon" href="images/favicon.ico" type="image/x-icon" />
#     <!-- <link href="./css/index.css" rel="stylesheet">
#     <link href="./css/global.css" rel="stylesheet">
#     <link href="./css/public.css" rel="stylesheet"> -->
#     <link href="./fonts/iconfont.css" rel="stylesheet">
#     <!-- æ¥æåå¸æ§ä»¶ -->
#     <!-- <link href="./css/common/calendarNew.css" rel="stylesheet">
#     <link href="./css/common/table.css" rel="stylesheet">
#     <link href="./css/common/station.css" rel="stylesheet">
#     <link rel="stylesheet" href="./css/main.css"> -->
#     <link rel="stylesheet" href="./css/index_y_v30001.css">
# </head>
# <style>
# ...
